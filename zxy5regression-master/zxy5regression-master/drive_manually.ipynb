# %%
from __future__ import print_function

import argparse
from pyglet.window import key
import gym
import numpy as np
import pickle
import os
from datetime import datetime
import gzip
import json

import copy

# %%
'''
def key_press(k, mod):
    global restart
    #if k == 0xff0d: restart = True
    if k == key.ESCAPE: restart = True
    if k == key.LEFT:  a[0] = -1.0
    if k == key.RIGHT: a[0] = +1.0
    if k == key.UP:    a[1] = +1.0
    if k == key.DOWN:  a[2] = +0.4  # stronger brakes
'''
#a[0]=steering
#a[1]=gas
#a[2]=brake
def key_press(k, mod):
    global restart
    #if k == 0xff0d: restart = True
    if k == key.ESCAPE: restart = True
    if k == key.UP:    
        a[3] = +1.0
        if a[0] == 0.0:
            a[1] = +1.0
    if k == key.LEFT:  
        a[0] = -1.0
        a[1] =  0.0  # Cut gas while turning
    if k == key.RIGHT: 
        a[0] = +1.0
        a[1] =  0.0  # Cut gas while turning
    if k == key.DOWN:  
        a[2] = +0.4  # stronger brakes

def key_release(k, mod):
    if k == key.LEFT and a[0] == -1.0: 
        a[0] = 0.0
        if a[3] == 1.0:
            a[1] = 1.0
    if k == key.RIGHT and a[0] == +1.0: 
        a[0] = 0.0
        if a[3] == 1.0:
            a[1] = 1.0
    if k == key.UP:    
        a[1] = 0.0
        a[3] = 0.0
    if k == key.DOWN:  
        a[2] = 0.0

# %%
def store_data(data, datasets_dir="./data"):
    # save data
    if not os.path.exists(datasets_dir):
        os.mkdir(datasets_dir)
    data_file = os.path.join(datasets_dir, 'data.pkl.gzip')
    f = gzip.open(data_file,'wb')
    pickle.dump(data, f)


def save_results(episode_rewards, results_dir="./results"):
    # save results
    if not os.path.exists(results_dir):
        os.mkdir(results_dir)

     # save statistics in a dictionary and write them into a .json file
    results = dict()
    results["number_episodes"] = len(episode_rewards)
    results["episode_rewards"] = episode_rewards

    results["mean_all_episodes"] = np.array(episode_rewards).mean()
    results["std_all_episodes"] = np.array(episode_rewards).std()
 
    fname = os.path.join(results_dir, "results_manually-%s.json" % datetime.now().strftime("%Y%m%d-%H%M%S"))
    fh = open(fname, "w")
    json.dump(results, fh)
    print('... finished')

# %%
    good_samples = {
        "state": [],
        "next_state": [],
        "reward": [],
        "action": [],
        "terminal" : [],
    }
    episode_samples = copy.deepcopy(good_samples)

    env = gym.make('CarRacing-v0').unwrapped
    env.reset()
    env.viewer.window.on_key_press = key_press
    env.viewer.window.on_key_release = key_release

    a = np.zeros(4, dtype=np.float32)
    
    episode_rewards = []
    good_steps = episode_steps = 0
    # Episode loop
    while True:
        episode_samples["state"] = []
        episode_samples["action"] = []
        episode_samples["next_state"] = []
        episode_samples["reward"] = []
        episode_samples["terminal"] = []
        episode_reward = 0
        state = env.reset()
        restart = False
        episode_steps = good_steps
        # State loop
        while True:
            next_state, r, done, info = env.step(a[:3])
            episode_reward += r

            episode_samples["state"].append(state)            # state has shape (96, 96, 3)
            episode_samples["action"].append(np.array(a[:3]))     # action has shape (1, 3)
            episode_samples["next_state"].append(next_state)
            episode_samples["reward"].append(r)
            episode_samples["terminal"].append(done)
            
            state = next_state
            episode_steps += 1
            env.render()
            
            if restart or done: 
                break
    
            if episode_steps % 1000 == 0 or done:
                print("\nstep {}".format(episode_steps))

           
            
            
        if not restart:
            good_steps = episode_steps

            episode_rewards.append(episode_reward)
            
            good_samples["state"].append(episode_samples["state"])
            good_samples["action"].append(episode_samples["action"])
            good_samples["next_state"].append(episode_samples["next_state"])
            good_samples["reward"].append(episode_samples["reward"])
            good_samples["terminal"].append(episode_samples["terminal"])

            print('... saving data')
            store_data(good_samples, "./data")
            save_results(episode_rewards, "./results")

    env.close()
# Out:
# Track generation: 1073..1354 -> 281-tiles track
# Track generation: 1176..1474 -> 298-tiles track
#
# step 1000
#
# step 2000
#
# step 3000
#
# step 4000
# Track generation: 1087..1363 -> 276-tiles track
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_19076/289054224.py in <module>
#      30     # State loop
#      31     while True:
# ---> 32         next_state, r, done, info = env.step(a[:3])
#      33         episode_reward += r
#      34
#
# ~/anaconda3/envs/test/lib/python3.7/site-packages/gym/envs/box2d/car_racing.py in step(self, action)
#     375         self.t += 1.0 / FPS
#     376
# --> 377         self.state = self.render("state_pixels")
#     378
#     379         step_reward = 0
#
# ~/anaconda3/envs/test/lib/python3.7/site-packages/gym/envs/box2d/car_racing.py in render(self, mode)
#     470
#     471         image_data = (
# --> 472             pyglet.image.get_buffer_manager().get_color_buffer().get_image_data()
#     473         )
#     474         arr = np.fromstring(image_data.get_data(), dtype=np.uint8, sep="")
#
# ~/anaconda3/envs/test/lib/python3.7/site-packages/pyglet/image/__init__.py in get_image_data(self)
#    2047         glPixelStorei(GL_PACK_ALIGNMENT, 1)
#    2048         glReadPixels(x, y, self.width, self.height,
# -> 2049                      self.gl_format, GL_UNSIGNED_BYTE, buffer)
#    2050         glPopClientAttrib()
#    2051
#
# ~/anaconda3/envs/test/lib/python3.7/site-packages/pyglet/gl/lib.py in errcheck(result, func, arguments)
#      85
#      86
# ---> 87 def errcheck(result, func, arguments):
#      88     if _debug_gl_trace:
#      89         try:
#
# KeyboardInterrupt:

# %%
env.close()

# %%
# !pip list
# Out:
# Package                    Version
# -------------------------- ------------
# absl-py                    0.15.0
# agent                      0.1.2
# ale-py                     0.7.4
# anyio                      3.5.0
# argon2-cffi                21.3.0
# argon2-cffi-bindings       21.2.0
# astor                      0.8.1
# astunparse                 1.6.3
# attrs                      22.1.0
# AutoROM                    0.4.2
# AutoROM.accept-rom-license 0.4.2
# Babel                      2.11.0
# backcall                   0.2.0
# beautifulsoup4             4.11.1
# bleach                     4.1.0
# Box2D                      2.3.10
# brotlipy                   0.7.0
# cached-property            1.5.2
# cachetools                 5.2.0
# carla                      0.9.13
# certifi                    2022.12.7
# cffi                       1.15.1
# charset-normalizer         2.1.1
# clang                      5.0
# click                      8.1.3
# cloudpickle                1.6.0
# commonmark                 0.9.1
# cryptography               38.0.4
# cycler                     0.11.0
# debugpy                    1.5.1
# decorator                  5.1.1
# defusedxml                 0.7.1
# elementpath                1.3.3
# entrypoints                0.4
# fastjsonschema             2.16.2
# flatbuffers                1.12
# flit_core                  3.6.0
# fonttools                  4.25.0
# gast                       0.4.0
# google-auth                2.14.1
# google-auth-oauthlib       0.4.6
# google-pasta               0.2.0
# grpcio                     1.50.0
# gym                        0.21.0
# h5py                       3.7.0
# idna                       3.4
# imageio                    2.22.4
# importlib-metadata         4.13.0
# importlib-resources        5.2.0
# ipykernel                  6.15.2
# ipython                    7.31.1
# ipython-genutils           0.2.0
# ipywidgets                 8.0.2
# jedi                       0.18.1
# Jinja2                     3.1.2
# json5                      0.9.6
# jsonschema                 4.16.0
# jupyter_client             7.4.8
# jupyter_core               4.11.2
# jupyter-server             1.23.4
# jupyterlab                 3.4.4
# jupyterlab-pygments        0.1.2
# jupyterlab_server          2.16.5
# jupyterlab-widgets         3.0.3
# keras                      2.11.0
# Keras-Applications         1.0.8
# Keras-Preprocessing        1.1.2
# kiwisolver                 1.4.4
# libclang                   14.0.6
# Markdown                   3.4.1
# MarkupSafe                 2.1.1
# matplotlib                 3.5.3
# matplotlib-inline          0.1.6
# mistune                    0.8.4
# mkl-fft                    1.3.1
# mkl-random                 1.2.2
# mkl-service                2.4.0
# munkres                    1.1.4
# nb-conda-kernels           2.3.1
# nbclassic                  0.4.8
# nbclient                   0.5.13
# nbconvert                  6.4.4
# nbformat                   5.7.0
# nest-asyncio               1.5.6
# networkx                   2.6.3
# notebook                   6.5.2
# notebook_shim              0.2.2
# numpy                      1.21.5
# oauthlib                   3.2.2
# opencv-python              4.6.0.66
# opt-einsum                 3.3.0
# packaging                  22.0
# pandas                     1.3.5
# pandocfilters              1.5.0
# parso                      0.8.3
# pexpect                    4.8.0
# pickleshare                0.7.5
# Pillow                     9.3.0
# pip                        22.3.1
# pkgutil_resolve_name       1.3.10
# ply                        3.11
# prometheus-client          0.14.1
# prompt-toolkit             3.0.36
# protobuf                   3.20.1
# psutil                     5.9.0
# ptyprocess                 0.7.0
# py-trees                   0.8.3
# pyasn1                     0.4.8
# pyasn1-modules             0.2.8
# pycparser                  2.21
# pyglet                     1.5.15
# Pygments                   2.11.2
# pyOpenSSL                  22.0.0
# pyparsing                  3.0.9
# PyQt5-sip                  12.11.0
# pyrsistent                 0.18.0
# PySocks                    1.7.1
# python-dateutil            2.8.2
# pytz                       2022.7
# PyWavelets                 1.3.0
# pyzmq                      23.2.0
# requests                   2.28.1
# requests-oauthlib          1.3.1
# rich                       12.6.0
# rsa                        4.9
# scikit-image               0.19.3
# scipy                      1.7.3
# Send2Trash                 1.8.0
# setuptools                 65.6.3
# simple-watchdog-timer      0.1.1
# sip                        6.6.2
# six                        1.16.0
# sniffio                    1.2.0
# soupsieve                  2.3.2.post1
# stable-baselines3          1.6.2
# tensorboard                1.15.0
# tensorflow                 1.15.0
# tensorflow-estimator       1.15.1
# termcolor                  1.1.0
# terminado                  0.17.1
# testpath                   0.6.0
# tifffile                   2021.11.2
# tinycss2                   1.2.1
# toml                       0.10.2
# torch                      1.13.0+cu116
# torchaudio                 0.13.0+cu116
# torchvision                0.14.0+cu116
# tornado                    6.2
# tqdm                       4.64.1
# traitlets                  5.7.1
# typing_extensions          4.4.0
# urllib3                    1.26.13
# utils                      1.0.1
# wcwidth                    0.2.5
# webencodings               0.5.1
# websocket-client           0.58.0
# Werkzeug                   2.2.2
# wheel                      0.37.1
# widgetsnbextension         4.0.3
# wrapt                      1.14.1
# xmlschema                  1.0.18
# zipp                       3.11.0
