# %%
import gym
import numpy as np
import os
from pyglet.window import key
import pickle, os, gzip
from datetime import datetime
from PIL import Image
from gym.envs.box2d.car_racing import CarRacing
from skimage.color import rgb2gray
import torch.nn as nn
import torch
import copy
import matplotlib.pyplot as plt

class User_Input:
    # car
    steering = 0
    gas = 0
    breaking = 0
    action = np.zeros(3, dtype=np.float32)
    # simulation
    escape = False
    record = False
    save = False
    reset = False
    # key press
    up = False
    down = False
    right = False
    left = False

    # setter from key press
    def on_key_press(self, k, mod):
        # car
        if k == key.UP:    self.up = True; return
        if k == key.LEFT:  self.left = True; return
        if k == key.RIGHT: self.right = True; return
        if k == key.DOWN:  self.down = True; return

        # simulation
        if k == key.SPACE: self.reset = True; return
        if k == key.ESCAPE:self.escape = True; return
        if k == key.R and self.record == False:  
            self.record = True
            print("start recording")
            return
        if k == key.R and self.record == True:   
            self.record = False
            self.save = True
            print("paused recording, start saving")
            return

    def on_key_release(self, k, mod):
        # car
        if k == key.UP:    self.up = False; return
        if k == key.LEFT:  self.left = False; return
        if k == key.RIGHT: self.right = False; return
        if k == key.DOWN:  self.down = False; return

    def check_arrow_keys(self):
        
        if (self.left):  
            self.steering -= 0.02
            if self.steering<-1:
                self.steering=-1
        if (self.right): 
            self.steering += 0.02
            if self.steering>1:
                self.steering=1
        if (self.up):    
            self.gas += 0.05
            if self.gas>1:
                self.gas=1
        if (self.down):  
            self.breaking += 0.02
            if self.breaking>1:
                self.steering=1
        if ((not self.left) and (not self.right)): self.steering = 0
        if (not self.up): self.gas = 0
        if (not self.down): self.breaking = 0 
        

        return
        

    # setter from action
    def on_save(self):
        self.save = False

    # getter
    def get_action(self):
        self.action[0] = self.steering
        self.action[1] = self.gas
        self.action[2] = self.breaking
        return self.action
    def escape_pressed(self):
        return self.escape
    def record_pressed(self):
        return self.record
    def save_pressed(self):
        return self.save
    def reset_pressed(self):
        return self.reset

    
class Data:
    data = {
        "state": [],
        "info" : [],
        "action": []
        }
    dir_folder = "./data2"

    def record(self, current_state, info, action):
        self.data["state"].append(copy.copy(current_state))
        self.data["info"].append(info)
        self.data["action"].append(copy.copy(action))
    
    def vstack(arr):
        stack = np.array(arr[0], dtype=np.float32)
        for i in range(1, len(arr)):
            stack = np.vstack((stack, arr[i]))
        return stack

    

    def read_data(self):
        """Reads the states and actions recorded in all files inside the given directory"""

        directory_path = os.path.join(os.getcwd(), "data2")
        print("Reading data from..." + directory_path)
        
        #initialise the list
        state = []
        action = []
        info = []
        
        for filename in os.listdir(directory_path):
            if filename.endswith(".pkl.gzip"):
                with gzip.open(os.path.join(directory_path, filename), 'rb') as f:
                    print(filename + " loaded")
                    data = pickle.load(f)
                    #append array into list
                    state.append(data["state"])
                    action.append(data["action"])
                    info.append(data["info"])
            
        s = self.vstack(state)
        a = self.vstack(action)
        i = self.vstack(info)
        
        print("All files added")
        print(s.shape)
        print(a.shape)
        print(i.shape)
        
        return s, a, i

    def save(self):

        # create folder if doesn't already exist
        if not os.path.exists(self.dir_folder):
            os.mkdir(self.dir_folder)

        # get file name
        file_name = str(datetime.now().strftime("%Y_%m_%d_%H-%M-%S"))+".pkl.gzip"
        dir_file = os.path.join(self.dir_folder, file_name)

        # save
        self.data["state"]=Data.preprocess_state(self.data["state"])
        print("image processed")
        f = gzip.open(dir_file, 'wb')
        pickle.dump(self.data, f)
        print("saved data to "+dir_file)

        # reset data
        self.data = {
            "state": [],
            "info" : [],
            "action": []}
    
    def plot_safety(info,i):
        speed = info[0]
        plt.plot(speed,i)
        plt.xlabel('frame')
        plt.ylabel('Speed')
        plt.show()

    def preprocess_state(states):
        """ Preprocess the images (states) of the expert dataset before feeding them to agent """
        states_pp = np.copy(states)
        
        # Paint black over the sum of rewards
        states_pp[:, 85:, :15] = [0.0, 0.0, 0.0]
        
        # Replace the colors defined bellow
        def replace_color(old_color, new_color, states_pp):
            mask = np.all(states_pp == old_color, axis=-1)
            states_pp[mask] = new_color
        
        # Black bar
        replace_color([0., 0., 0.], [120.0, 120.0, 120.0], states_pp)
        #print("black bar replaced")
        # Road
        new_road_color = [102.0, 102.0, 102.0]
        replace_color([102., 102., 102.], new_road_color, states_pp)
        replace_color([105., 105., 105.], new_road_color, states_pp)
        replace_color([107., 107., 107.], new_road_color, states_pp)
        #print("road replaced")
        # Curbs
        replace_color([255., 0., 0.], new_road_color, states_pp)
        replace_color([255., 255., 255.], new_road_color, states_pp)
        #print("curb replaced")

        # Grass
        #new_grass_color = [0.0, 0.0, 0.0]
        new_grass_color = [102., 229., 102.]
        replace_color([102., 229., 102.], new_grass_color, states_pp)
        replace_color([102., 204., 102.], new_grass_color, states_pp)
        #print("grass replaced")
        # Float RGB represenattion
        #states_pp /= 255.

        # Converting to gray scale
        states_pp = rgb2gray(states_pp)

        return states_pp
    
class Simulation:
    #env = gym.make('CarRacing-v0').unwrapped
    env = CarRacing()
    user_input = User_Input()
    current_state = np.ndarray((96, 96, 3))
    data = Data()
    step = 0

    def __init__(self):
        # initialize window
        self.current_state = self.env.reset()
        # assign key action
        self.env.viewer.window.on_key_press     = self.user_input.on_key_press
        self.env.viewer.window.on_key_release   = self.user_input.on_key_release

    def run_simulation(self):
        while True:
            

            # act                
            next_state, reward, done, info = self.env.step(self.user_input.get_action())
            
            # render
            isopen = self.env.render()
            self.step += 1
            if self.step % 1000 == 0:
                print(f'step number has been {self.step}')
                
            # update control
            self.user_input.check_arrow_keys()

            # ---------- ACTIONS ----------
            # close window 
            if (self.user_input.escape_pressed()) : 
                self.env.close()
                break

            # record data
            if (self.user_input.record_pressed()):
                self.data.record(self.current_state, self.env.read_info(), self.user_input.get_action())
                #print(self.user_input.get_action())
            if (self.user_input.save_pressed()):
                self.data.save()
                self.user_input.on_save()


            # --------- NEXT LOOP ---------
            self.current_state = next_state
            if done or self.user_input.reset==True or isopen == False:
                self.env.reset()
                self.user_input.reset = False
    
    def test_simulation(self, model):
        while True:
            # Define a state to test the model on
            state = Data.preprocess_state(self.current_state)
            info = self.env.read_info()#

            # Wrap the state and info in Tensors and add a batch dimension
            state = torch.tensor(state).unsqueeze(0).unsqueeze(0).to(torch.float32)
            info = torch.tensor(info).unsqueeze(0).to(torch.float32)

            # Pass the state and info through the model and get the output action
            action = model((state, info))
            # Convert tensor to tuple
            action = tuple(action.squeeze().tolist())

            print(f"The model output action is: {action}")
            
            # act                
            next_state, reward, done, info = self.env.step(action)
            
            # render
            isopen = self.env.render()
            self.step += 1
            if self.step % 1000 == 0:
                print(f'step number has been {self.step}')
                
            # update control
            self.user_input.check_arrow_keys()

            # ---------- ACTIONS ----------
            # close window 
            if (self.user_input.escape_pressed()) : 
                self.env.close()
                break

            # --------- NEXT LOOP ---------
            self.current_state = next_state
            if done or self.user_input.reset==True or isopen == False:
                self.env.reset()
                self.user_input.reset = False
    

    def dagger(self,model):
        max_timesteps=1000
        n_test_episodes = 10
        episode_reward = 0
        episode_rewards = []#To record the average reward
        good_expert=0

        for i in range(n_test_episodes):
            self.data.data["state"]=[]
            self.data.data["info"]=[]
            self.data.data["action"]=[]
            state = self.env.reset()
            episode_reward = 0
            for _ in range(max_timesteps):
                # Define a state to test the model on
                state = preprocess_state(self.current_state)
                info = self.env.read_info()#

                # Wrap the state and info in Tensors and add a batch dimension
                state = torch.tensor(state).unsqueeze(0).unsqueeze(0).to(torch.float32)
                info = torch.tensor(info).unsqueeze(0).to(torch.float32)

                # Pass the state and info through the model and get the output action
                action = model((state, info))
                # Convert tensor to tuple
                action = tuple(action.squeeze().tolist())
                
                # act                
                next_state, reward, done, info = self.env.step(action)
                # record
                episode_reward += reward
                self.data.record(self.current_state, info, action)

                
                # render
                isopen = self.env.render()
                self.current_state = next_state
                self.step += 1

                if done:
                    break

                # ---------- ACTIONS ----------
                # close window 
                if (self.user_input.escape_pressed()) : 
                    self.env.close()
                    break

                # --------- NEXT LOOP ---------
                if self.user_input.reset==True or isopen == False:
                    self.env.reset()
                    self.user_input.reset = False
            if (i+1) % 10 ==0:
                print(f'Episode {i+1}') 
            episode_rewards.append(episode_reward)
            
            if episode_reward > 1000:
                good_expert+=1
                print(f'GOOD EXPERT with reward {episode_reward}') 
                self.data.save()
        self.env.close()
        average = sum(episode_rewards) / len(episode_rewards)
        print(f"-------------AVERAGE REWARD: {average}")
        print(f"-------------No.GOOD EXPERT: {good_expert} out of {n_test_episodes} experts")

# %%
simulation = Simulation()
simulation.run_simulation()
#simulation.test_simulation()
# Out:
# Track generation: 1375..1723 -> 348-tiles track
# start recording
# step number has been 1000
# step number has been 2000
# Track generation: 1315..1648 -> 333-tiles track
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-41-18.pkl.gzip
# start recording
# step number has been 3000
# step number has been 4000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-42-08.pkl.gzip
# step number has been 5000
# Track generation: 1259..1578 -> 319-tiles track
# start recording
# step number has been 6000
# step number has been 7000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-42-53.pkl.gzip
# Track generation: 1207..1519 -> 312-tiles track
# start recording
# step number has been 8000
# step number has been 9000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-43-40.pkl.gzip
# Track generation: 1228..1537 -> 309-tiles track
# start recording
# step number has been 10000
# Track generation: 1051..1318 -> 267-tiles track
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-44-08.pkl.gzip
# Track generation: 1245..1560 -> 315-tiles track
# start recording
# step number has been 11000
# step number has been 12000
# Track generation: 1172..1469 -> 297-tiles track
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-44-35.pkl.gzip
# Track generation: 995..1254 -> 259-tiles track
# start recording
# step number has been 13000
# step number has been 14000
# Track generation: 1162..1457 -> 295-tiles track
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-45-13.pkl.gzip
# Track generation: 1151..1450 -> 299-tiles track
# start recording
# step number has been 15000
# step number has been 16000
# Track generation: 1108..1389 -> 281-tiles track
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-45-57.pkl.gzip
# Track generation: 1072..1353 -> 281-tiles track
# start recording
# step number has been 17000
# step number has been 18000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-46-39.pkl.gzip
# Track generation: 1180..1479 -> 299-tiles track
# start recording
# step number has been 19000
# step number has been 20000
# Track generation: 1163..1458 -> 295-tiles track
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-47-14.pkl.gzip
# Track generation: 1144..1433 -> 289-tiles track
# start recording
# step number has been 21000
# step number has been 22000
# Track generation: 1198..1502 -> 304-tiles track
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-47-56.pkl.gzip
# Track generation: 988..1239 -> 251-tiles track
# start recording
# step number has been 23000
# Track generation: 1137..1429 -> 292-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1205..1510 -> 305-tiles track
# step number has been 24000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-48-37.pkl.gzip
# Track generation: 1352..1694 -> 342-tiles track
# start recording
# step number has been 25000
# step number has been 26000
# Track generation: 1380..1738 -> 358-tiles track
# step number has been 27000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-49-37.pkl.gzip
# Track generation: 1136..1424 -> 288-tiles track
# step number has been 28000
# start recording
# step number has been 29000
# Track generation: 1293..1621 -> 328-tiles track
# step number has been 30000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-50-36.pkl.gzip
# Track generation: 1143..1433 -> 290-tiles track
# start recording
# step number has been 31000
# step number has been 32000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-51-20.pkl.gzip
# Track generation: 1140..1429 -> 289-tiles track
# step number has been 33000
# start recording
# step number has been 34000
# Track generation: 1203..1515 -> 312-tiles track
# step number has been 35000
# step number has been 36000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-52-19.pkl.gzip
# Track generation: 1280..1604 -> 324-tiles track
# step number has been 37000
# Track generation: 1185..1485 -> 300-tiles track
# start recording
# step number has been 38000
# step number has been 39000
# Track generation: 1128..1414 -> 286-tiles track
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-53-28.pkl.gzip
# Track generation: 1097..1377 -> 280-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1171..1468 -> 297-tiles track
# Track generation: 1328..1664 -> 336-tiles track
# start recording
# step number has been 40000
# step number has been 41000
# step number has been 42000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-54-17.pkl.gzip
# Track generation: 1190..1497 -> 307-tiles track
# start recording
# step number has been 43000
# Track generation: 1075..1352 -> 277-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1117..1400 -> 283-tiles track
# step number has been 44000
# Track generation: 1252..1569 -> 317-tiles track
# step number has been 45000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-55-25.pkl.gzip
# Track generation: 1169..1465 -> 296-tiles track
# step number has been 46000
# start recording
# step number has been 47000
# Track generation: 983..1239 -> 256-tiles track
# step number has been 48000
# Track generation: 1256..1574 -> 318-tiles track
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-56-25.pkl.gzip
# start recording
# step number has been 49000
# step number has been 50000
# Track generation: 1153..1453 -> 300-tiles track
# step number has been 51000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-57-15.pkl.gzip
# Track generation: 1183..1489 -> 306-tiles track
# start recording
# step number has been 52000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-57-47.pkl.gzip
# Track generation: 1264..1584 -> 320-tiles track
# start recording
# step number has been 53000
# step number has been 54000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-58-14.pkl.gzip
# Track generation: 1104..1384 -> 280-tiles track
# step number has been 55000
# Track generation: 1156..1449 -> 293-tiles track
# step number has been 56000
# start recording
# Track generation: 1047..1321 -> 274-tiles track
# step number has been 57000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-59-17.pkl.gzip
# start recording
# Track generation: 1128..1414 -> 286-tiles track
# step number has been 58000
# Track generation: 900..1130 -> 230-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1099..1378 -> 279-tiles track
# step number has been 59000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_21-59-58.pkl.gzip
# Track generation: 1224..1534 -> 310-tiles track
# step number has been 60000
# start recording
# step number has been 61000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_22-00-28.pkl.gzip
# Track generation: 1367..1713 -> 346-tiles track
# Track generation: 1239..1560 -> 321-tiles track
# Track generation: 1372..1719 -> 347-tiles track
# start recording
# step number has been 62000
# step number has been 63000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_22-01-05.pkl.gzip
# Track generation: 1167..1464 -> 297-tiles track
# start recording
# step number has been 64000
# paused recording, start saving
# image processed
# saved data to ./data2/2023_02_26_22-01-32.pkl.gzip
# Track generation: 999..1260 -> 261-tiles track
# step number has been 65000
# Track generation: 1067..1338 -> 271-tiles track
# step number has been 66000
# step number has been 67000
# Track generation: 1088..1364 -> 276-tiles track
# step number has been 68000
# step number has been 69000
# Track generation: 1297..1625 -> 328-tiles track

# %%
import os
import gzip
import pickle
import numpy as np
from torch.utils.data import Dataset, DataLoader
import random
import torch

class MyDataset(Dataset):
    def __init__(self, directory_path, batch_size, train_frac):
        self.paths = []
        self.data = []
        self.batch_size = batch_size
        self.directory_path = directory_path
        self.train_frac = train_frac
        self.zerocount = 0
        self.invalidcount = 0

        # iterate over all files in the directory
        for filename in os.listdir(directory_path):
            if filename.endswith(".pkl.gzip"):
                with gzip.open(os.path.join(self.directory_path, filename), 'rb') as f:
                    data = pickle.load(f)
                    for state, info, action in zip(data["state"], data["info"], data["action"]):
                        self.data.append((state, info, action))
                        if self.num_zero(action):
                            self.zerocount += 1

        random.shuffle(self.data)
    
        # split the data into train and validation sets
        num_train = int(len(self.data) * train_frac)
        self.train_data = self.data[:num_train]
        self.val_data = self.data[num_train:]

    def __getitem__(self, index):
        if index < len(self.train_data):
            state, info, action = self.train_data[index]
        else:
            state, info, action = self.val_data[index - len(self.train_data)]

        return torch.tensor(state), torch.tensor(info), torch.tensor(action)

    def __len__(self):
        if self.batch_size == 1:
            return len(self.train_data) + len(self.val_data)
        else:
            return len(self.train_data) // self.batch_size + len(self.val_data) // self.batch_size

    def num_zero(self, arr):
        if (arr == [0, 0, 0]).all():
            return True
        else:
            return False

# directory containing the dataset files
directory_path = os.path.join(os.getcwd(), "data2")

# Create dataset
dataset = MyDataset(directory_path=directory_path, batch_size=256, train_frac=0.9)

# Create samplers
train_sampler = torch.utils.data.SubsetRandomSampler(range(len(dataset.train_data)))
val_sampler = torch.utils.data.SubsetRandomSampler(range(len(dataset.train_data), len(dataset.data)))

# Create Dataloader
train_dataloader = DataLoader(dataset, batch_size=256, drop_last=True, num_workers=4, pin_memory=True, sampler=train_sampler)
val_dataloader = DataLoader(dataset, batch_size=256, drop_last=True, num_workers=4, pin_memory=True, sampler=val_sampler)

print("Total number of data points:", len(dataset.train_data) + len(dataset.val_data))
print("Number of [0, 0, 0] actions:", dataset.zerocount)

print("Length of train_dataloader:", len(train_dataloader))
print("Length of val_dataloader:", len(val_dataloader))
# Out:
# Total number of data points: 55287
# Number of [0, 0, 0] actions: 26097
# Length of train_dataloader: 194
# Length of val_dataloader: 21
